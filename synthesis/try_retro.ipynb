# %%
import pandas as pd
df = pd.read_parquet('sample_reactants.parquet')
df= df[df['num_occurrences'] > 50]
df = df.sample(n=50_000)
df['fingerprint'] = get 1024 fingerprints for all the smiles
df.to_parquet('50k_reactants.parquet')

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
df[df['num_occurrences'] > 50]
# Out:
#                                    smiles  num_occurrences
# 0                                      CO          3807579
# 1                                     CBr          3349318
# 2                           NC[B-](F)(F)F          1363015
# 3                      O=C(Cl)[B-](F)(F)F           750850
# 4                           CC[B-](F)(F)F           730434
# ...                                   ...              ...
# 119989       CC(C)(C)[C@H]1C[C@@H](N)CCO1               51
# 119990  CC[C@](C)(N)CNC(=O)C=C[B-](F)(F)F               51
# 119991              NC(=O)C[C@H](Br)C1CC1               51
# 119992            CNS(=O)(=O)c1cccc(Cl)c1               51
# 119993       C[C@@H](N1CCSCC1)[B-](F)(F)F               51
#
# [119994 rows x 2 columns]
